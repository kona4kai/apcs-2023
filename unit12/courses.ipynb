# %% [markdown]
# # Courses and Teachers!

# %%
# first, import the re module to use python's regular expressions
import re

# %%
with open('datasets/ahs23-24/courses.txt', 'r') as fp:
    courses_upper = fp.read()
courses_upper
# Out:
# '1.0 ENGLISH 9 (WITH HONORS OPTIONS) EN100A 0.5 SPORTS & CONDITIONING PE100A 0.5 PAINTING I & II AR150A\n1.0 ENGLISH 10 (WITH HONORS OPTIONS) EN200A 0.5 SPORTS & CONDITIONING PE100B 0.5 PAINTING I &II AR150B\n1.0 ENGLISH 11 EN300A 0.5 STRENGTH & CONDITIONING PE130A 0.5 DRAWING I & II AR100A\n1.0 ENGLISH 12 BRIDGE TO COLLEGE EN420A 0.5 STRENGTH & CONDITIONING PE130B 0.5 DRAWING I & II AR100B\n1.0 AP LANGUAGE / ENGLISH COMP 101 (CIH) EN710A 0.5 CARDIO CORE PE140A 0.5 CERAMICS I & II AR200A\n1.0 AP ENGLISH LITERATURE EN720A 0.5 CARDIO CORE PE140B 0.5 CERAMICS I & II AR200B\n0.5 SCULPUTRE I & II AR240A\n0.5 SCULPTURE I & II AR240B\n0.5 WORLD HISTORY SS100A 0.5 HEALTH HLT101 0.5 DRAMA I DRA110\n1.0 AP HUMAN GEOGRAHPHY SS700A 0.5 DRAMA II DRA200\n1.0 US HISTORY SS200A 1.0 DRAMA III DRA300\n1.0 AP US HISTORY SS720A 0.5 ENGINEERING DRAWING / DESIGN I & II VOC425 0.5 CHOIR MU100A\n0.5 CONTEMPORARY WORLD ISSUES (CWI) SS330A 0.5 ARCHITECTURAL DRAWING I & II VOC430 0.5 CHOIR MU100B\n0.5 CONTEMPORARY AMERICAN CULTURE (CAC) SS310A 1.0 YEARBOOK (Application Req) VOC575 0.5 SYMPHONIC BAND MU600A\n0.5 CIVICS SS300A 1.0 YEARBOOK LAB (Editors Only) VOC517 0.5 SYMPHONIC BAND MU600B\n0.5 CONTEMPORARY ISSUES THRU MULTI MEDIA SS320A 0.5 MICROSOFT IT ACADEMY VOC534 0.5 WIND ENSEMBLE (Audition Req.) MU620A\n1.0 AP US GOVERNMENT SS730A 0.5 ADV MICROSOFT IT ACADEMY VOC535 0.5 WIND ENSEMBLE (Audition Req.) MU620B\n1.0 HON RELIGIONS / HIST 121 REL OF WRLD (CIH) SS400A 0.5 INTRO TO COMPUTER SCIENCE VCT300 0.5 PERCUSSION MU640A\n0.5 DIGITAL MEDIA PRODUCTION VOC560 0.5 PERCUSSION MU640B\n1.0 ADV DIGITAL MEDIA (Application Req) VOC565 0.5 GUITAR MU500A\n1.0 BIOLOGY/EARTH SC120A 0.5 COMMERCIAL PHOTOGRAPHY I & II VOC570 0.5 GUITAR MU500B\n1.0 CHEMISTRY SC220A 0.5 COMMERCIAL PHOTOGRAPHY I & II VOC571 0.25 JAZZ CHOIR A (Audition Req.) MU800A\n1.0 PHYSICS SC720A 0.5 MARKETING VOC630 0.25 JAZZ CHOIR B (Audition Req.) MU800B\n1.0 AP PHYSICS I SC730A 0.5 ADV MARKETING VOC632 0.25 JAZZ BAND A (Audition Req.) MU820A\n0.5 ROBOTICS I SC300A 0.5 STUDENT STORE VOC635 0.25 JAZZ BAND B (Audition Req.) MU820B\n0.5 ROBOTICS II-III SC300B 0.5 STUDENT STORE VOC636\n1.0 AP ENVIRONMENTAL SCIENCE SC700A 0.5 PERSONAL FINANCE I VOC740 ADDITIONAL ELECTIVES\n0.5 PERSONAL FINANCE II VOC741 1.0 STUDY SKILLS A & B MIS053\n1.0 HUMAN ANATOMY / PHYSIOLOGY VOC616 1.0 SENIOR SEMINAR A & B / CSS 103 (CIH) CIHSSA\n1.0 ALGEBRA I MA130A 0.5 SPORTS MEDICINE I VOC620 0.5 TECH THEATRE (Permission Req.) DT500A\n1.0 GEOMETRY MA140A 0.5 SPORTS MEDICINE II VOC621 0.5 TECH THEATRE (Permission Req.) DT500B\n1.0 BRIDGE TO COLLEGE MATH 11TH-12TH MA310A 0.5 METALS I - IV VOC831 0.5 STUDENT LEADERSHIP (Application Req) STLEA1\n1.0 ALGEBRA II MA150A 0.5 METALS I - IV VOC832 0.5 STUDENT LEADERSHIP (Application Req) STLEA2\n1.0 ALGEBRA II HONORS MA155A 0.5 WOOD TECH I & II VOC911 1.0 2024 ANACORTES COLLEGE PREP ACP24A\n1.0 ALGEBRA II HON AB / AP PRE-CALC AB MA15AB 0.5 WOOD TECH I & II VOC912 1.0 2025 ANACORTES COLLEGE PREP ACP25A\n1.0 ALGEBRA II HON AB / AP PRE-CALC AB MA20AB 1.0 2026 ANACORTES COLLEGE PREP ACP26A\n1.0 AP PRE CALCULUS MA210A WORLD LANGUAGE\n1.0 AP CALCULUS AB/BC MA700A 1.0 SPANISH I WL100A\n1.0 AP STATISTICS MA720A 1.0 SPANISH II WL200A\n1.0 SPANISH III / SPAN 123 (CIH) WL310A\n1.0 SPANISH IV / SPAN 221 (CIH) WL410A\n1.0 AP SPANISH LANG & CULTURE (SPANISH V) WL710'

# %%
# find a six-character run of capital/number surrounded by whitespace \s
pattern = "\s([A-Z0-9]{6})\s"
# find credits, course, and symbol
pattern = r"(1.0|0.5|0.25) ([\w\s\(\)\&\-\/]+(?:Req\.\))?) ([A-Z0-9]{5,6})"
courses = re.findall(pattern, courses_upper)
print(len(courses), "courses matched")
courses
# Out:
# 103 courses matched
# [('1.0', 'ENGLISH 9 (WITH HONORS OPTIONS)', 'EN100A'),
#  ('0.5', 'SPORTS & CONDITIONING', 'PE100A'),
#  ('0.5', 'PAINTING I & II', 'AR150A'),
#  ('1.0', 'ENGLISH 10 (WITH HONORS OPTIONS)', 'EN200A'),
#  ('0.5', 'SPORTS & CONDITIONING', 'PE100B'),
#  ('0.5', 'PAINTING I &II', 'AR150B'),
#  ('1.0', 'ENGLISH 11', 'EN300A'),
#  ('0.5', 'STRENGTH & CONDITIONING', 'PE130A'),
#  ('0.5', 'DRAWING I & II', 'AR100A'),
#  ('1.0', 'ENGLISH 12 BRIDGE TO COLLEGE', 'EN420A'),
#  ('0.5', 'STRENGTH & CONDITIONING', 'PE130B'),
#  ('0.5', 'DRAWING I & II', 'AR100B'),
#  ('1.0', 'AP LANGUAGE / ENGLISH COMP 101 (CIH)', 'EN710A'),
#  ('0.5', 'CARDIO CORE', 'PE140A'),
#  ('0.5', 'CERAMICS I & II', 'AR200A'),
#  ('1.0', 'AP ENGLISH LITERATURE', 'EN720A'),
#  ('0.5', 'CARDIO CORE', 'PE140B'),
#  ('0.5', 'CERAMICS I & II', 'AR200B'),
#  ('0.5', 'SCULPUTRE I & II', 'AR240A'),
#  ('0.5', 'SCULPTURE I & II', 'AR240B'),
#  ('0.5', 'WORLD HISTORY', 'SS100A'),
#  ('0.5', 'HEALTH', 'HLT101'),
#  ('0.5', 'DRAMA I', 'DRA110'),
#  ('1.0', 'AP HUMAN GEOGRAHPHY', 'SS700A'),
#  ('0.5', 'DRAMA II', 'DRA200'),
#  ('1.0', 'US HISTORY', 'SS200A'),
#  ('1.0', 'DRAMA III', 'DRA300'),
#  ('1.0', 'AP US HISTORY', 'SS720A'),
#  ('0.5', 'ENGINEERING DRAWING / DESIGN I & II', 'VOC425'),
#  ('0.5', 'CHOIR', 'MU100A'),
#  ('0.5', 'CONTEMPORARY WORLD ISSUES (CWI)', 'SS330A'),
#  ('0.5', 'ARCHITECTURAL DRAWING I & II', 'VOC430'),
#  ('0.5', 'CHOIR', 'MU100B'),
#  ('0.5', 'CONTEMPORARY AMERICAN CULTURE (CAC)', 'SS310A'),
#  ('1.0', 'YEARBOOK (Application Req)', 'VOC575'),
#  ('0.5', 'SYMPHONIC BAND', 'MU600A'),
#  ('0.5', 'CIVICS', 'SS300A'),
#  ('1.0', 'YEARBOOK LAB (Editors Only)', 'VOC517'),
#  ('0.5', 'SYMPHONIC BAND', 'MU600B'),
#  ('0.5', 'CONTEMPORARY ISSUES THRU MULTI MEDIA', 'SS320A'),
#  ('0.5', 'MICROSOFT IT ACADEMY', 'VOC534'),
#  ('0.5', 'WIND ENSEMBLE (Audition Req.)', 'MU620A'),
#  ('1.0', 'AP US GOVERNMENT', 'SS730A'),
#  ('0.5', 'ADV MICROSOFT IT ACADEMY', 'VOC535'),
#  ('0.5', 'WIND ENSEMBLE (Audition Req.)', 'MU620B'),
#  ('1.0', 'HON RELIGIONS / HIST 121 REL OF WRLD (CIH)', 'SS400A'),
#  ('0.5', 'INTRO TO COMPUTER SCIENCE', 'VCT300'),
#  ('0.5', 'PERCUSSION', 'MU640A'),
#  ('0.5', 'DIGITAL MEDIA PRODUCTION', 'VOC560'),
#  ('0.5', 'PERCUSSION', 'MU640B'),
#  ('1.0', 'ADV DIGITAL MEDIA (Application Req)', 'VOC565'),
#  ('0.5', 'GUITAR', 'MU500A'),
#  ('1.0', 'BIOLOGY/EARTH', 'SC120A'),
#  ('0.5', 'COMMERCIAL PHOTOGRAPHY I & II', 'VOC570'),
#  ('0.5', 'GUITAR', 'MU500B'),
#  ('1.0', 'CHEMISTRY', 'SC220A'),
#  ('0.5', 'COMMERCIAL PHOTOGRAPHY I & II', 'VOC571'),
#  ('0.25', 'JAZZ CHOIR A (Audition Req.)', 'MU800A'),
#  ('1.0', 'PHYSICS', 'SC720A'),
#  ('0.5', 'MARKETING', 'VOC630'),
#  ('0.25', 'JAZZ CHOIR B (Audition Req.)', 'MU800B'),
#  ('1.0', 'AP PHYSICS I', 'SC730A'),
#  ('0.5', 'ADV MARKETING', 'VOC632'),
#  ('0.25', 'JAZZ BAND A (Audition Req.)', 'MU820A'),
#  ('0.5', 'ROBOTICS I', 'SC300A'),
#  ('0.5', 'STUDENT STORE', 'VOC635'),
#  ('0.25', 'JAZZ BAND B (Audition Req.)', 'MU820B'),
#  ('0.5', 'ROBOTICS II-III', 'SC300B'),
#  ('0.5', 'STUDENT STORE', 'VOC636'),
#  ('1.0', 'AP ENVIRONMENTAL SCIENCE', 'SC700A'),
#  ('0.5', 'PERSONAL FINANCE I VOC740 ADDITIONAL', 'ELECTI'),
#  ('0.5', 'PERSONAL FINANCE II', 'VOC741'),
#  ('1.0', 'STUDY SKILLS A & B', 'MIS053'),
#  ('1.0', 'HUMAN ANATOMY / PHYSIOLOGY', 'VOC616'),
#  ('1.0', 'SENIOR SEMINAR A & B / CSS 103 (CIH)', 'CIHSSA'),
#  ('1.0', 'ALGEBRA I', 'MA130A'),
#  ('0.5', 'SPORTS MEDICINE I', 'VOC620'),
#  ('0.5', 'TECH THEATRE (Permission Req.)', 'DT500A'),
#  ('1.0', 'GEOMETRY', 'MA140A'),
#  ('0.5', 'SPORTS MEDICINE II', 'VOC621'),
#  ('0.5', 'TECH THEATRE (Permission Req.)', 'DT500B'),
#  ('1.0', 'BRIDGE TO COLLEGE MATH 11TH-12TH', 'MA310A'),
#  ('0.5', 'METALS I - IV', 'VOC831'),
#  ('0.5', 'STUDENT LEADERSHIP (Application Req)', 'STLEA1'),
#  ('1.0', 'ALGEBRA II', 'MA150A'),
#  ('0.5', 'METALS I - IV', 'VOC832'),
#  ('0.5', 'STUDENT LEADERSHIP (Application Req)', 'STLEA2'),
#  ('1.0', 'ALGEBRA II HONORS', 'MA155A'),
#  ('0.5', 'WOOD TECH I & II', 'VOC911'),
#  ('1.0', '2024 ANACORTES COLLEGE PREP', 'ACP24A'),
#  ('1.0', 'ALGEBRA II HON AB / AP PRE-CALC AB', 'MA15AB'),
#  ('0.5', 'WOOD TECH I & II', 'VOC912'),
#  ('1.0', '2025 ANACORTES COLLEGE PREP', 'ACP25A'),
#  ('1.0', 'ALGEBRA II HON AB / AP PRE-CALC AB', 'MA20AB'),
#  ('1.0', '2026 ANACORTES COLLEGE PREP', 'ACP26A'),
#  ('1.0', 'AP PRE CALCULUS MA210A WORLD', 'LANGUA'),
#  ('1.0', 'AP CALCULUS AB/BC', 'MA700A'),
#  ('1.0', 'SPANISH I', 'WL100A'),
#  ('1.0', 'AP STATISTICS', 'MA720A'),
#  ('1.0', 'SPANISH II', 'WL200A'),
#  ('1.0', 'SPANISH III / SPAN 123 (CIH)', 'WL310A'),
#  ('1.0', 'SPANISH IV / SPAN 221 (CIH)', 'WL410A'),
#  ('1.0', 'AP SPANISH LANG & CULTURE (SPANISH V)', 'WL710')]

# %%
with open('datasets/ahs23-24/courses-frosh.txt', 'r') as fp:
    courses_frosh = fp.read()
courses_frosh
# Out:
# '2023 - 2024 Course Availabiltiy\nClass of 2027\n1.0 9TH ENGLISH (W/ HONORS OPTION) EN100A 0.5 ENGINEERING DRAW / DESIGN I & II VOC425\n0.5 ARCHITECTURAL DRAWING I & II VOC430\n0.5 MICROSOFT IT ACADEMY VOC534\n0.5 WORLD HISTORY SS100A 0.5 ADV MICROSOFT IT ACADEMY VOC535\n1.0 AP HUMAN GEOGRAPHY SS700A 0.5 INTRO COMPUTER SCIENCE VCT300\n0.5 DIGITAL MEDIA PRODUCTION VOC560\n1.0 ADV DIG MEDIA (Application Req) VOC565\n1.0 BIOLOGY / EARTH SC120A 0.5 COMMERCIAL PHOTOGRAPHY I & II VOC570\n1.0 CHEMISTRY (Pre Req Alg I) SC220A 0.5 COMMERCIAL PHOTOGRAPHY I & II VOC571\n0.5 ROBOTICS I & II SC300A 1.0 YEARBOOK (Application Req) VOC575\n0.5 ROBOTICS I & II SC300B 0.5 INTRO TO MARKETING VOC630\n0.5 ADVANCED MARKETING VOC632\n0.5 METALS I & II VOC831\n0.5 METALS I & II VOC832\n1.0 ALGEBRA I MA130A 0.5 WOOD TECH I & II VOC911\n1.0 GEOMETRY MA140A 0.5 WOOD TECH I & II VOC912\n1.0 ALGEBRA II MA150A\n1.0 ALGEBRA II HONORS MA155A FINE ARTS\n0.5 DRAWING I & II AR100A\n0.5 DRAWING I & II AR100B\n0.5 SPORTS & CONDITIONING PE100A 0.5 PAINTING I & II AR150A\n0.5 SPORTS & CONDITIONING PE100B 0.5 PAINTING I & II AR150B\n0.5 STRENGTH & CONDITIONING PE130A 0.5 SCULPTURE I & II AR240A\n0.5 STRENGTH & CONDITIONING PE130B 0.5 SCULPUTRE I & II AR240B\n0.5 CARDIO CORE PE140A 0.5 DRAMA I DRA110\n0.5 CARDIO CORE PE140B 0.5 DRAMA II DRA200\n0.5 TECH THEATRE (Application Req.) DT500A\n0.5 TECH THEATRE (Application Req.) DT500B\n0.5 HEALTH HLT101 0.5 CHOIR MU100A\n0.5 CHOIR MU100B\n0.5 SYMPHONIC BAND MU600A\n0.5 SYMPHONIC BAND MU600B\n0.5 PERCUSSION A MU640A\n0.5 PERCUSSION B MU640B\n0.5 WIND ENSEMBLE (Audition Req.) MU620A\n0.5 WIND ENSEMBLE (Audition Req.) MU620B\n1.0 SPANISH I WL100A\n1.0 SPANISH II WL200A\n1.0 ALG I SUPPORT (IF ASSIGNED) MA100A\n1.0 2027 ANACORTES COLLEGE PREP ACP27A\n1.0 STUDY SKILLS A & B MIS053\n'

# %%
# find a six-character run of capital/number surrounded by whitespace \s
pattern = "\s([A-Z0-9]{6})\s"
# find credits, course, and symbol
pattern = r"(1.0|0.5|0.25) ([\w\s\(\)\&\-\/]+(?:Req\.\))?) ([A-Z0-9]{5,6})"
courses = re.findall(pattern, courses_frosh)
print(len(courses), "courses matched")
courses
# Out:
# 57 courses matched
# [('1.0', '9TH ENGLISH (W/ HONORS OPTION)', 'EN100A'),
#  ('0.5', 'ENGINEERING DRAW / DESIGN I & II', 'VOC425'),
#  ('0.5', 'ARCHITECTURAL DRAWING I & II', 'VOC430'),
#  ('0.5', 'MICROSOFT IT ACADEMY', 'VOC534'),
#  ('0.5', 'WORLD HISTORY', 'SS100A'),
#  ('0.5', 'ADV MICROSOFT IT ACADEMY', 'VOC535'),
#  ('1.0', 'AP HUMAN GEOGRAPHY', 'SS700A'),
#  ('0.5', 'INTRO COMPUTER SCIENCE', 'VCT300'),
#  ('0.5', 'DIGITAL MEDIA PRODUCTION', 'VOC560'),
#  ('1.0', 'ADV DIG MEDIA (Application Req)', 'VOC565'),
#  ('1.0', 'BIOLOGY / EARTH', 'SC120A'),
#  ('0.5', 'COMMERCIAL PHOTOGRAPHY I & II', 'VOC570'),
#  ('1.0', 'CHEMISTRY (Pre Req Alg I)', 'SC220A'),
#  ('0.5', 'COMMERCIAL PHOTOGRAPHY I & II', 'VOC571'),
#  ('0.5', 'ROBOTICS I & II', 'SC300A'),
#  ('1.0', 'YEARBOOK (Application Req)', 'VOC575'),
#  ('0.5', 'ROBOTICS I & II', 'SC300B'),
#  ('0.5', 'INTRO TO MARKETING', 'VOC630'),
#  ('0.5', 'ADVANCED MARKETING', 'VOC632'),
#  ('0.5', 'METALS I & II', 'VOC831'),
#  ('0.5', 'METALS I & II', 'VOC832'),
#  ('1.0', 'ALGEBRA I', 'MA130A'),
#  ('0.5', 'WOOD TECH I & II', 'VOC911'),
#  ('1.0', 'GEOMETRY', 'MA140A'),
#  ('0.5', 'WOOD TECH I & II', 'VOC912'),
#  ('1.0', 'ALGEBRA II', 'MA150A'),
#  ('1.0', 'ALGEBRA II HONORS', 'MA155A'),
#  ('0.5', 'DRAWING I & II', 'AR100A'),
#  ('0.5', 'DRAWING I & II', 'AR100B'),
#  ('0.5', 'SPORTS & CONDITIONING', 'PE100A'),
#  ('0.5', 'PAINTING I & II', 'AR150A'),
#  ('0.5', 'SPORTS & CONDITIONING', 'PE100B'),
#  ('0.5', 'PAINTING I & II', 'AR150B'),
#  ('0.5', 'STRENGTH & CONDITIONING', 'PE130A'),
#  ('0.5', 'SCULPTURE I & II', 'AR240A'),
#  ('0.5', 'STRENGTH & CONDITIONING', 'PE130B'),
#  ('0.5', 'SCULPUTRE I & II', 'AR240B'),
#  ('0.5', 'CARDIO CORE', 'PE140A'),
#  ('0.5', 'DRAMA I', 'DRA110'),
#  ('0.5', 'CARDIO CORE', 'PE140B'),
#  ('0.5', 'DRAMA II', 'DRA200'),
#  ('0.5', 'TECH THEATRE (Application Req.)', 'DT500A'),
#  ('0.5', 'TECH THEATRE (Application Req.)', 'DT500B'),
#  ('0.5', 'HEALTH', 'HLT101'),
#  ('0.5', 'CHOIR', 'MU100A'),
#  ('0.5', 'CHOIR', 'MU100B'),
#  ('0.5', 'SYMPHONIC BAND', 'MU600A'),
#  ('0.5', 'SYMPHONIC BAND', 'MU600B'),
#  ('0.5', 'PERCUSSION A', 'MU640A'),
#  ('0.5', 'PERCUSSION B', 'MU640B'),
#  ('0.5', 'WIND ENSEMBLE (Audition Req.)', 'MU620A'),
#  ('0.5', 'WIND ENSEMBLE (Audition Req.)', 'MU620B'),
#  ('1.0', 'SPANISH I', 'WL100A'),
#  ('1.0', 'SPANISH II', 'WL200A'),
#  ('1.0', 'ALG I SUPPORT (IF ASSIGNED)', 'MA100A'),
#  ('1.0', '2027 ANACORTES COLLEGE PREP', 'ACP27A'),
#  ('1.0', 'STUDY SKILLS A & B', 'MIS053')]

# %%
with open('datasets/ahs23-24/skyward-courses.txt', 'r') as fp:
    data = fp.read()
data
# Out:
# 'ACP24A\tANACORTES COLLEGE PREP 2024\n0.500 Credits,  Elective\nACP24B\tANACORTES COLLEGE PREP 2024\n0.500 Credits,  Elective\nAR100A\tDRAWING\n0.500 Credits,  Elective\nAR100B\tDRAWING II\n0.500 Credits,  Elective\nAR150A\tPAINTING\n0.500 Credits,  Elective\nAR150B\tPAINTING II\n0.500 Credits,  Elective\nAR240A\tSCULPTURE\n0.500 Credits,  Elective\nAR240B\tSCULPTURE II\n0.500 Credits,  Elective\nCIHSSA\tSENIOR SEMINAR\n0.500 Credits,  Elective\nCIHSSB\tSENIOR SEMINAR\n0.500 Credits,  Elective\nDRA110\tDRAMA I\n0.500 Credits,  Elective\nDRA200\tDRAMA II\n0.500 Credits,  Elective\nDRA300\tDRAMA III\n0.500 Credits,  Elective\nDRA301\tDRAMA III\n0.500 Credits,  Elective\nDT500A\tADV TECHNICAL THEATRE\n0.500 Credits,  Elective\nDT500B\tADV TECH THEATRE\n0.500 Credits,  Elective\nEN420A\tENGLISH 12 BTC\n0.500 Credits,  Required\nEN420B\tENGLISH 12 BTC\n0.500 Credits,  Required\nEN720A\tAP LITERATURE\n0.500 Credits,  Required\nEN720B\tAP LITERATURE\n0.500 Credits,  Required\nMA150A\tALGEBRA II\n0.500 Credits,  Required\nMA150B\tALGEBRA II\n0.500 Credits,  Required\nMA155A\tALG II HONORS\n0.500 Credits,  Required\nMA155B\tALG II HONORS\n0.500 Credits,  Required\nMIS053\tSTUDY SKILLS A\n0.500 Credits,  Required\nMIS054\tSTUDY SKILLS B\n0.500 Credits,  Required\nMU100A\tCHOIR\n0.500 Credits,  Required\nMU100B\tCHOIR\n0.500 Credits,  Required\nMU600A\tSYMPHONIC BAND\n0.500 Credits,  Required\nMU600B\tSYMPHONIC BAND\n0.500 Credits,  Required\nMU620A\tWIND ENSEMBLE\n0.500 Credits,  Elective\nMU620B\tWIND ENSEMBLE\n0.500 Credits,  Elective\nMU640A\tPERCUSSION ENSEMBLE\n0.500 Credits,  Elective\nMU640B\tPERCUSSION ENSEMBLE\n0.500 Credits,  Elective\nPE100A\tSPORTS/CONDITIONING\n0.500 Credits,  Elective\nPE100B\tSPORTS CONDITIONING\n0.500 Credits,  Elective\nPE130A\tSTRENGTH CONDITIONING\n0.500 Credits,  Elective\nPE130B\tSTRENGTH CONDITIONING\n0.500 Credits,  Elective\nPE140A\tCARDIO CORE\n0.500 Credits,  Elective\nPE140B\tCARDIO CORE\n0.500 Credits,  Elective\nSC220A\tCHEMISTRY\n0.500 Credits,  Required\nSC220B\tCHEMISTRY\n0.500 Credits,  Required\nSC300A\tROBOTICS\n0.500 Credits,  Required\nSC300B\tROBOTICS\n0.500 Credits,  Required\nSC700A\tAP ENV SCIENCE\n0.500 Credits,  Required\nSC700B\tAP ENV SCIENCE\n0.500 Credits,  Required\nSC720A\tPHYSICS A\n0.500 Credits,  Required\nSC720B\tPHYSICS B\n0.500 Credits,  Required\nSC730A\tAP PHYSICS SCIENCE A\n0.500 Credits,  Required\nSC730B\tAP PHYSICS SCIENCE B\n0.500 Credits,  Required\nSS300A\tCIVICS\n0.500 Credits,  Required\nSS310A\tCONT AMER CULTURE\n0.500 Credits,  Required\nSS320A\tCONT ISSUES/MEDIA\n0.500 Credits,  Required\nSS330A\tCONT WORLD ISSUES\n0.500 Credits,  Required\nSS400A\tHON CONT ISSUES/RELIGIONS A\n0.500 Credits,  Required\nSS400B\tHON CONT ISSUES/RELIGIONS B\n0.500 Credits,  Required\nSS730A\tAP US GOV/POL A\n0.500 Credits,  Required\nSS730B\tAP US GOV/POL B\n0.500 Credits,  Required\nSTLEA1\tSTUD LEAD/GOVT\n0.500 Credits,  Elective\nSTLEA2\tSTUD LEAD/GOVT\n0.500 Credits,  Elective\nVCT300\tINTRO COMP SCIENCE\n0.500 Credits,  Elective\nVOC425\tENG DRAW&DES I/CNC MACHINE\n0.500 Credits,  Elective\nVOC426\tENG DRAWING & DESIGN II\n0.500 Credits,  Elective\nVOC430\tARCH DRAW/DSGN\n0.500 Credits,  Elective\nVOC431\tARCHITEC DRAWING & DESIGN II\n0.500 Credits,  Elective\nVOC517\tYEARBOOK LAB\n0.500 Credits,  Elective\nVOC519\tYEARBOOK LAB II\n0.500 Credits,  Elective\nVOC534\tMS 2010 IT ACADEMY\n0.500 Credits,  Elective\nVOC535\tADV MS 2010 IT ACADEMY\n0.500 Credits,  Elective\nVOC560\tDIGITAL MEDIA PRODUCTION\n0.500 Credits,  Elective\nVOC565\tADV DIGITAL MEDIA A\n0.500 Credits,  Elective\nVOC566\tADV DIGITAL MEDIA B\n0.500 Credits,  Elective\nVOC570\tCOMMERCIAL PHOTOGRAPHY\n0.500 Credits,  Elective\nVOC571\tCOMMERCIAL PHOTOGRAPHY II\n0.500 Credits,  Elective\nVOC575\tYEARBOOK A\n0.500 Credits,  Elective\nVOC576\tYEARBOOK B\n0.500 Credits,  Elective\nVOC616\tHUMAN ANATOMY\n0.500 Credits,  Elective\nVOC617\tHUMAN ANATOMY\n0.500 Credits,  Elective\nVOC620\tSPORTS MEDICINE I\n0.5 ...

# %%
# find a six-character run of capital/number followed by a \t (tab character)
pattern = r"([A-Z0-9]{6})\t(.*)\n([\d\.]+) Credits,  (Elective|Required)"
# find symbol, course, and credits, and elective/required
courses = re.findall(pattern, data)
print(len(courses), "courses matched")
courses
# Out:
# 100 courses matched
# [('ACP24A', 'ANACORTES COLLEGE PREP 2024', '0.500', 'Elective'),
#  ('ACP24B', 'ANACORTES COLLEGE PREP 2024', '0.500', 'Elective'),
#  ('AR100A', 'DRAWING', '0.500', 'Elective'),
#  ('AR100B', 'DRAWING II', '0.500', 'Elective'),
#  ('AR150A', 'PAINTING', '0.500', 'Elective'),
#  ('AR150B', 'PAINTING II', '0.500', 'Elective'),
#  ('AR240A', 'SCULPTURE', '0.500', 'Elective'),
#  ('AR240B', 'SCULPTURE II', '0.500', 'Elective'),
#  ('CIHSSA', 'SENIOR SEMINAR', '0.500', 'Elective'),
#  ('CIHSSB', 'SENIOR SEMINAR', '0.500', 'Elective'),
#  ('DRA110', 'DRAMA I', '0.500', 'Elective'),
#  ('DRA200', 'DRAMA II', '0.500', 'Elective'),
#  ('DRA300', 'DRAMA III', '0.500', 'Elective'),
#  ('DRA301', 'DRAMA III', '0.500', 'Elective'),
#  ('DT500A', 'ADV TECHNICAL THEATRE', '0.500', 'Elective'),
#  ('DT500B', 'ADV TECH THEATRE', '0.500', 'Elective'),
#  ('EN420A', 'ENGLISH 12 BTC', '0.500', 'Required'),
#  ('EN420B', 'ENGLISH 12 BTC', '0.500', 'Required'),
#  ('EN720A', 'AP LITERATURE', '0.500', 'Required'),
#  ('EN720B', 'AP LITERATURE', '0.500', 'Required'),
#  ('MA150A', 'ALGEBRA II', '0.500', 'Required'),
#  ('MA150B', 'ALGEBRA II', '0.500', 'Required'),
#  ('MA155A', 'ALG II HONORS', '0.500', 'Required'),
#  ('MA155B', 'ALG II HONORS', '0.500', 'Required'),
#  ('MIS053', 'STUDY SKILLS A', '0.500', 'Required'),
#  ('MIS054', 'STUDY SKILLS B', '0.500', 'Required'),
#  ('MU100A', 'CHOIR', '0.500', 'Required'),
#  ('MU100B', 'CHOIR', '0.500', 'Required'),
#  ('MU600A', 'SYMPHONIC BAND', '0.500', 'Required'),
#  ('MU600B', 'SYMPHONIC BAND', '0.500', 'Required'),
#  ('MU620A', 'WIND ENSEMBLE', '0.500', 'Elective'),
#  ('MU620B', 'WIND ENSEMBLE', '0.500', 'Elective'),
#  ('MU640A', 'PERCUSSION ENSEMBLE', '0.500', 'Elective'),
#  ('MU640B', 'PERCUSSION ENSEMBLE', '0.500', 'Elective'),
#  ('PE100A', 'SPORTS/CONDITIONING', '0.500', 'Elective'),
#  ('PE100B', 'SPORTS CONDITIONING', '0.500', 'Elective'),
#  ('PE130A', 'STRENGTH CONDITIONING', '0.500', 'Elective'),
#  ('PE130B', 'STRENGTH CONDITIONING', '0.500', 'Elective'),
#  ('PE140A', 'CARDIO CORE', '0.500', 'Elective'),
#  ('PE140B', 'CARDIO CORE', '0.500', 'Elective'),
#  ('SC220A', 'CHEMISTRY', '0.500', 'Required'),
#  ('SC220B', 'CHEMISTRY', '0.500', 'Required'),
#  ('SC300A', 'ROBOTICS', '0.500', 'Required'),
#  ('SC300B', 'ROBOTICS', '0.500', 'Required'),
#  ('SC700A', 'AP ENV SCIENCE', '0.500', 'Required'),
#  ('SC700B', 'AP ENV SCIENCE', '0.500', 'Required'),
#  ('SC720A', 'PHYSICS A', '0.500', 'Required'),
#  ('SC720B', 'PHYSICS B', '0.500', 'Required'),
#  ('SC730A', 'AP PHYSICS SCIENCE A', '0.500', 'Required'),
#  ('SC730B', 'AP PHYSICS SCIENCE B', '0.500', 'Required'),
#  ('SS300A', 'CIVICS', '0.500', 'Required'),
#  ('SS310A', 'CONT AMER CULTURE', '0.500', 'Required'),
#  ('SS320A', 'CONT ISSUES/MEDIA', '0.500', 'Required'),
#  ('SS330A', 'CONT WORLD ISSUES', '0.500', 'Required'),
#  ('SS400A', 'HON CONT ISSUES/RELIGIONS A', '0.500', 'Required'),
#  ('SS400B', 'HON CONT ISSUES/RELIGIONS B', '0.500', 'Required'),
#  ('SS730A', 'AP US GOV/POL A', '0.500', 'Required'),
#  ('SS730B', 'AP US GOV/POL B', '0.500', 'Required'),
#  ('STLEA1', 'STUD LEAD/GOVT', '0.500', 'Elective'),
#  ('STLEA2', 'STUD LEAD/GOVT', '0.500', 'Elective'),
#  ('VCT300', 'INTRO COMP SCIENCE', '0.500', 'Elective'),
#  ('VOC425', 'ENG DRAW&DES I/CNC MACHINE', '0.500', 'Elective'),
#  ('VOC426', 'ENG DRAWING & DESIGN II', '0.500', 'Elective'),
#  ('VOC430', 'ARCH DRAW/DSGN', '0.500', 'Elective'),
#  ('VOC431', 'ARCHITEC DRAWING & DESIGN II', '0.500', 'Elective'),
#  ('VOC517', 'YEARBOOK LAB', '0.500', 'Elective'),
#  ('VOC519', 'YEARBOOK LAB II', '0.500', 'Elective'),
#  ('VOC534', 'MS 2010 IT ACADEMY', '0.500', 'Elective'),
#  ('VOC535', 'ADV MS 2010 IT ACADEMY', '0.500', 'Elective'),
#  ('VOC560', 'DIGITAL MEDIA PRODUCTION', '0.500', 'Elective'),
#  ('VOC565', 'ADV DIGITAL MEDIA A', '0.500', 'Elective'),
#  ('VOC566', 'ADV DIGITAL MEDIA B', '0.500', 'Elective'),
#  ('VOC570', 'COMMERCIAL PHOTOGRAPHY', '0.500', 'Elective'),
#  ('VOC571', 'COMMERCIAL PHOTOGRAPHY II', '0.500', 'Elective'),
#  ('VOC575', 'YEARBOOK A', '0.500', 'Elective'),
#  ('VOC576', 'YEARBOOK B', '0.500', 'Elective'),
#  ('VOC616', 'HUMAN ANATOMY', '0.500', 'Elective'),
#  ('VOC617', 'HUMAN ANATOMY', '0.500', 'Elective'),
#  ('VOC620', 'SPORTS MEDICINE I', '0.500', 'Elective'),
#  ('VOC621', 'SPORTS MEDICINE II', '0.500', 'Elective'),
#  ('VOC630', 'MARKETING', '0.500', 'Elective'),
#  ('VOC632', 'ADV MARKETING', '0.500', 'Elective'),
#  ('VOC635', 'STUDENT STORE', '0.500', 'Elective'),
#  ('VOC636', 'STUDENT STORE', '0.500', 'Elective'),
#  ('VOC740', 'PERSONAL FINANCE I', '0.500', 'Elective'),
#  ('VOC741', 'PERSONAL FINANCE II', '0.500', 'Elective'),
#  ('VOC831', 'METALS TECH I', '0.500', 'Elective'),
#  ('VOC832', 'METALS TECH II', '0.500', 'Elective'),
#  ('VOC911', 'WOODTECHNOLOGY I', '0.500', 'Elective'),
#  ('VOC912', 'WOODWORKING TECHNOLOGY II', '0.500', 'Elective'),
#  ('WL100A', 'SPANISH I', '0.500', 'Required'),
#  ('WL100B', 'SPANISH I', '0.500', 'Required'),
#  ('WL200A', 'SPANISH II', '0.500', 'Required'),
#  ('WL200B', 'SPANISH II', '0.500', 'Required'),
#  ('WL310A', 'SPAN 123 SPANISH III', '0.500', 'Elective'),
#  ('WL310B', 'SPAN 123 SPANISH III', '0.500', 'Elective'),
#  ('WL410A', 'SPAN 221 SPANISH IV', '0.500', 'Elective'),
#  ('WL410B', 'SPAN 221 SPANISH IV', '0.500', 'Elective'),
#  ('WL710A', 'AP SPANISH LANG & CULTURE', '0.500', 'Elective'),
#  ('WL710B', 'AP SPANISH LANGUAGE & CULTURE', '0.500', 'Elective')]

# %%
def parse_courses():
    courses = []
    with open('datasets/ahs23-24/skyward-courses.txt', "r") as file:
        coursedata = file.read()
    # group name syntax: https://docs.python.org/3/library/re.html#re.Match.group
    for item in re.finditer('(?P<key>[A-Z0-9]{6})\t(?P<course>.+)\n(?P<credits>[\d\.]+) Credits,  (?P<type>Elective|Required)', coursedata):
        foo = item.groupdict()
        foo['credits'] = float(foo['credits'])
        courses.append(foo)
    return courses

courses = parse_courses()
print(len(courses), "courses matched")
courses
# Out:
# 100 courses matched
# [{'key': 'ACP24A',
#   'course': 'ANACORTES COLLEGE PREP 2024',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'ACP24B',
#   'course': 'ANACORTES COLLEGE PREP 2024',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'AR100A', 'course': 'DRAWING', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'AR100B', 'course': 'DRAWING II', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'AR150A', 'course': 'PAINTING', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'AR150B',
#   'course': 'PAINTING II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'AR240A', 'course': 'SCULPTURE', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'AR240B',
#   'course': 'SCULPTURE II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'CIHSSA',
#   'course': 'SENIOR SEMINAR',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'CIHSSB',
#   'course': 'SENIOR SEMINAR',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'DRA110', 'course': 'DRAMA I', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'DRA200', 'course': 'DRAMA II', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'DRA300', 'course': 'DRAMA III', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'DRA301', 'course': 'DRAMA III', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'DT500A',
#   'course': 'ADV TECHNICAL THEATRE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'DT500B',
#   'course': 'ADV TECH THEATRE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'EN420A',
#   'course': 'ENGLISH 12 BTC',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'EN420B',
#   'course': 'ENGLISH 12 BTC',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'EN720A',
#   'course': 'AP LITERATURE',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'EN720B',
#   'course': 'AP LITERATURE',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MA150A', 'course': 'ALGEBRA II', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'MA150B', 'course': 'ALGEBRA II', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'MA155A',
#   'course': 'ALG II HONORS',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MA155B',
#   'course': 'ALG II HONORS',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MIS053',
#   'course': 'STUDY SKILLS A',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MIS054',
#   'course': 'STUDY SKILLS B',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MU100A', 'course': 'CHOIR', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'MU100B', 'course': 'CHOIR', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'MU600A',
#   'course': 'SYMPHONIC BAND',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MU600B',
#   'course': 'SYMPHONIC BAND',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'MU620A',
#   'course': 'WIND ENSEMBLE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'MU620B',
#   'course': 'WIND ENSEMBLE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'MU640A',
#   'course': 'PERCUSSION ENSEMBLE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'MU640B',
#   'course': 'PERCUSSION ENSEMBLE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE100A',
#   'course': 'SPORTS/CONDITIONING',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE100B',
#   'course': 'SPORTS CONDITIONING',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE130A',
#   'course': 'STRENGTH CONDITIONING',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE130B',
#   'course': 'STRENGTH CONDITIONING',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE140A',
#   'course': 'CARDIO CORE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'PE140B',
#   'course': 'CARDIO CORE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'SC220A', 'course': 'CHEMISTRY', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC220B', 'course': 'CHEMISTRY', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC300A', 'course': 'ROBOTICS', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC300B', 'course': 'ROBOTICS', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC700A',
#   'course': 'AP ENV SCIENCE',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SC700B',
#   'course': 'AP ENV SCIENCE',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SC720A', 'course': 'PHYSICS A', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC720B', 'course': 'PHYSICS B', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SC730A',
#   'course': 'AP PHYSICS SCIENCE A',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SC730B',
#   'course': 'AP PHYSICS SCIENCE B',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS300A', 'course': 'CIVICS', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'SS310A',
#   'course': 'CONT AMER CULTURE',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS320A',
#   'course': 'CONT ISSUES/MEDIA',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS330A',
#   'course': 'CONT WORLD ISSUES',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS400A',
#   'course': 'HON CONT ISSUES/RELIGIONS A',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS400B',
#   'course': 'HON CONT ISSUES/RELIGIONS B',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS730A',
#   'course': 'AP US GOV/POL A',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'SS730B',
#   'course': 'AP US GOV/POL B',
#   'credits': 0.5,
#   'type': 'Required'},
#  {'key': 'STLEA1',
#   'course': 'STUD LEAD/GOVT',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'STLEA2',
#   'course': 'STUD LEAD/GOVT',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VCT300',
#   'course': 'INTRO COMP SCIENCE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC425',
#   'course': 'ENG DRAW&DES I/CNC MACHINE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC426',
#   'course': 'ENG DRAWING & DESIGN II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC430',
#   'course': 'ARCH DRAW/DSGN',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC431',
#   'course': 'ARCHITEC DRAWING & DESIGN II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC517',
#   'course': 'YEARBOOK LAB',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC519',
#   'course': 'YEARBOOK LAB II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC534',
#   'course': 'MS 2010 IT ACADEMY',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC535',
#   'course': 'ADV MS 2010 IT ACADEMY',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC560',
#   'course': 'DIGITAL MEDIA PRODUCTION',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC565',
#   'course': 'ADV DIGITAL MEDIA A',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC566',
#   'course': 'ADV DIGITAL MEDIA B',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC570',
#   'course': 'COMMERCIAL PHOTOGRAPHY',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC571',
#   'course': 'COMMERCIAL PHOTOGRAPHY II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC575', 'course': 'YEARBOOK A', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'VOC576', 'course': 'YEARBOOK B', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'VOC616',
#   'course': 'HUMAN ANATOMY',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC617',
#   'course': 'HUMAN ANATOMY',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC620',
#   'course': 'SPORTS MEDICINE I',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC621',
#   'course': 'SPORTS MEDICINE II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC630', 'course': 'MARKETING', 'credits': 0.5, 'type': 'Elective'},
#  {'key': 'VOC632',
#   'course': 'ADV MARKETING',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC635',
#   'course': 'STUDENT STORE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC636',
#   'course': 'STUDENT STORE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC740',
#   'course': 'PERSONAL FINANCE I',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC741',
#   'course': 'PERSONAL FINANCE II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC831',
#   'course': 'METALS TECH I',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC832',
#   'course': 'METALS TECH II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC911',
#   'course': 'WOODTECHNOLOGY I',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'VOC912',
#   'course': 'WOODWORKING TECHNOLOGY II',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL100A', 'course': 'SPANISH I', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'WL100B', 'course': 'SPANISH I', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'WL200A', 'course': 'SPANISH II', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'WL200B', 'course': 'SPANISH II', 'credits': 0.5, 'type': 'Required'},
#  {'key': 'WL310A',
#   'course': 'SPAN 123 SPANISH III',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL310B',
#   'course': 'SPAN 123 SPANISH III',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL410A',
#   'course': 'SPAN 221 SPANISH IV',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL410B',
#   'course': 'SPAN 221 SPANISH IV',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL710A',
#   'course': 'AP SPANISH LANG & CULTURE',
#   'credits': 0.5,
#   'type': 'Elective'},
#  {'key': 'WL710B',
#   'course': 'AP SPANISH LANGUAGE & CULTURE',
#   'credits': 0.5,
#   'type': 'Elective'}]

# %%
import re
import csv

def parse_filename_with_regex(filename, regex):
    courses = []
    with open(filename, "r") as file:
        coursedata = file.read()
    
    for item in regex.finditer(coursedata):
        course = item.groupdict()
        course['credits'] = float(course['credits'])
        courses.append(course)
    return courses

skyward_regex = re.compile(r"(?P<key>[A-Z0-9]{6})\t(?P<course>.+)\n(?P<credits>[\d\.]+) Credits,  (?P<type>Elective|Required)")
ahs_regex = re.compile(r"(?P<credits>1.0|0.5|0.25) (?P<course>[\w\s\(\)\&\-\/]+(?:Req\.\))?) (?P<key>[A-Z0-9]{5,6})")
skyware_file = 'datasets/ahs23-24/skyward-courses.txt'
courses_frosh_file = 'datasets/ahs23-24/courses-frosh.txt'
courses_file = 'datasets/ahs23-24/courses.txt'

all_courses = []
all_courses.extend(parse_filename_with_regex(skyware_file,skyward_regex))
all_courses.extend(parse_filename_with_regex(courses_file,ahs_regex))
all_courses.extend(parse_filename_with_regex(courses_frosh_file,ahs_regex))

outfile = 'datasets/courses.csv'
with open(outfile, 'w') as csvfile:
    fieldnames = ['key','course','credits','type']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for course in sorted(all_courses, key=lambda course: course['key']):
        writer.writerow(course)

print("wrote",len(all_courses),"courses to",outfile)
# Out:
# wrote 260 courses to datasets/courses.csv

# %% [markdown]
# What can we discover with this data?
# - How many teachers does the school need to run this course load?  How many periods do they teach?
# - If we were going to schedule classes, what algorithm can we imagine?
# - How do we de-dupe this data?

# %%
# let's group courses by key prefix (excluding A/B suffix)
course_prefix = dict()
max_for_prefix = 0
for course in all_courses:
    prefix = course['key']
    if prefix[-1] in "AB":
        prefix = prefix[:-1]
    course_prefix[prefix] = course_prefix.get(prefix, [])
    course_prefix[prefix].append(course)
    if len(course_prefix[prefix]) > max_for_prefix:
        max_for_prefix = len(course_prefix[prefix])

# maximum number of courses for prefix
print("max courses in a group:", max_for_prefix) 
# how many courses now?
print("courses:", len(course_prefix))
course_prefix

# %%
# for a group of courses, remove duplicates
def dedupe_course(courses):
    # map courses by key, check types are the same
    merged = dict()
    types = set()
    for c in courses:
        if 'type' in c:
            types.add(c['type'])
            del c['type']
        merged[c['key']] = merged.get(c['key'],[])
        merged[c['key']].append(c)
    # courses should not be both required and elective
    assert len(types) <= 1
    assert len(merged) <= 3 # A, B, both
    course_type = None
    if len(types) == 1:
        course_type = types.pop()
    # consolidate same-key courses into one course with aliases and minimum credits    
    # because 1.0 course is often coded with 1st semester key
    for course_key in merged:
        course = merged[course_key][0]        
        for alias in merged[course_key][1:]:
            course['credits'] = min(course['credits'], alias['credits'])
            if alias['course'] != course['course']:
                course['alias'] = course.get('alias', [])
                if alias['course'] not in course['alias']:
                    course['alias'].append(alias['course'])
        if course_type:
            course['type'] = course_type
        merged[course_key] = course
    # link courses as related
    distinct_courses = list(merged.values())
    related_keys = set([c['key'] for c in distinct_courses])
    for course in distinct_courses:
        course['related'] = [k for k in related_keys if k != course['key']]
    if len(course['related']) == 0:
        del course['related']
    return distinct_courses

# now we should have max 3 courses pre prefix
max_for_prefix = 0
for prefix in course_prefix:
    course_prefix[prefix] = dedupe_course(course_prefix[prefix])
    if len(course_prefix[prefix]) > max_for_prefix:
        max_for_prefix = len(course_prefix[prefix])    

max_for_prefix

# %%
from pprint import pprint
# or max 2, except for one exception:
for prefix in course_prefix:
    if len(course_prefix[prefix]) > 2:
        pprint(course_prefix[prefix])

# %%
# output our cleaned data
outfile = 'datasets/courses2.csv'
with open(outfile, 'w') as csvfile:
    fieldnames = ['key','course','alias','credits','type', 'related']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for prefix in sorted(course_prefix):
        for course in course_prefix[prefix]:
            writer.writerow(course)

print("wrote courses to",outfile)
